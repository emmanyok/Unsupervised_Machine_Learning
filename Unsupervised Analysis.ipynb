# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
# import the standard scaler
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# # Part 1: Prepare the Data

# %%
# Import the data
file_path = './Resources/myopia.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
# List features
df.columns
# Out:
# Index(['AGE', 'SPHEQ', 'AL', 'ACD', 'LT', 'VCD', 'SPORTHR', 'READHR', 'COMPHR',
#        'STUDYHR', 'TVHR', 'DIOPTERHR', 'MOMMY', 'DADMY', 'MYOPIC'],
#       dtype='object')

# %%
df.dtypes
# Out:
# AGE            int64
# SPHEQ        float64
# AL           float64
# ACD          float64
# LT           float64
# VCD          float64
# SPORTHR        int64
# READHR         int64
# COMPHR         int64
# STUDYHR        int64
# TVHR           int64
# DIOPTERHR      int64
# MOMMY          int64
# DADMY          int64
# MYOPIC         int64
# dtype: object

# %%
# Remove the Myopic column since we are running models without training, labels not needed
new_df= df.drop(['MYOPIC'], axis=1)
new_df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0        0    10         34      1      1
# 1        1     7         12      1      1
# 2        0    10         14      0      0
# 3        0     4         37      0      1
# 4        0     4          4      1      0

# %%
# Find null values
for column in new_df.columns:
    print(f"Column {column} has {new_df[column].isnull().sum()} null values")
# Out:
# Column AGE has 0 null values
# Column SPHEQ has 0 null values
# Column AL has 0 null values
# Column ACD has 0 null values
# Column LT has 0 null values
# Column VCD has 0 null values
# Column SPORTHR has 0 null values
# Column READHR has 0 null values
# Column COMPHR has 0 null values
# Column STUDYHR has 0 null values
# Column TVHR has 0 null values
# Column DIOPTERHR has 0 null values
# Column MOMMY has 0 null values
# Column DADMY has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {new_df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(new_df)

# %%
# Create a DataFrame with the transformed data
final_df = pd.DataFrame(scaled_data, columns=new_df.columns)

# %%
# Save the cleaned DataFrame as a new CSV file for further use
file = Path("new_data.csv")
final_df.to_csv(file, index=False)

# %% [markdown]
# # Part 2: Dimension Reduction

# %%
# Applying PCA to preserve approximately 90% of the explained variance

# Initialize PCA model
pca = PCA(n_components=0.9)

# Get principal components 
myopia_pca = pca.fit_transform(scaled_data)
myopia_pca.shape
# Out:
# (618, 10)

# %%
 # Fetch the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.21177355, 0.15659716, 0.08688023, 0.08301762, 0.07584858,
#        0.06997878, 0.06486986, 0.06377808, 0.05393666, 0.05205566])

# %%
# Transform PCA data to a DataFrame
df_myopia_pca = pd.DataFrame(
    data=myopia_pca, columns=["principal component 1", "principal component 2", "principal component 3", 
                              "principal component 4", "principal component 5", "principal component 6",
                              "principal component 7", "principal component 8","principal component 9",
                             "principal component 10",]
)
df_myopia_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               0.535503               1.145004              -1.385019
# 1              -0.624706              -1.575786              -0.794253
# 2              -0.933479              -0.717076               0.820150
# 3               0.106354               1.192475              -0.024441
# 4              -0.388503              -2.839655              -0.229767
#
#    principal component 4  principal component 5  principal component 6  \
# 0               0.116006              -3.226691              -1.928459
# 1               1.156287               0.292256               0.349060
# 2              -1.547638               0.173941               0.272783
# 3               1.507469              -2.356836              -0.023139
# 4              -0.622510               0.271458              -0.928956
#
#    principal component 7  principal component 8  principal component 9  \
# 0              -1.958892              -1.922997               0.026753
# 1              -0.455206               0.285332               0.689683
# 2               0.025821              -0.030817              -0.431499
# 3               0.236418              -1.717109              -1.230785
# 4               0.537900              -1.301787               0.279007
#
#    principal component 10
# 0                0.178144
# 1               -0.557031
# 2                0.013336
# 3               -0.703400
# 4                0.631183

# %%
### TSNE Mod

# %%
 # Initialize t-SNE model
tsne = TSNE(learning_rate=15)

# %%
# Reduce dimensions
tsne_features = tsne.fit_transform(df_myopia_pca)
# The dataset has 2 columns
tsne_features.shape
# Out:
# C:\Users\Emmanuel\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (618, 2)

# %%
# Prepare to plot the dataset

# The first column of transformed features
df_myopia_pca['x'] = tsne_features[:,0]

# The second column of transformed features
df_myopia_pca['y'] = tsne_features[:,1]

# %%
labels = df['MYOPIC']
labels.value_counts().nunique()
# Out:
# 2

# %%
# Visualize the clusters
plt.scatter(df_myopia_pca['x'], df_myopia_pca['y'], c=labels)
plt.show()

# %% [markdown]
# # Part 3: Cluster Analysis with K-means

# %%
# Create an elbow plot to identify the best number of clusters
inertia = []
k = list(range(1, 10))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(final_df)
    inertia.append(km.inertia_)

# Create dataframe for plotting
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
# C:\Users\Emmanuel\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
#    k      inertia
# 0  1  8652.000000
# 1  2  7497.115123
# 2  3  6732.095466
# 3  4  6362.286058
# 4  5  6083.180361

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,10))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for Myopia data')
plt.show()

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=5, random_state=0)

# Fit the model
model.fit(df_myopia_pca)

# Predict clusters
predictions = model.predict(df_myopia_pca)

# Add the predicted class column for plotting
df_myopia_pca["class"] = model.labels_
df_myopia_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               0.535503               1.145004              -1.385019
# 1              -0.624706              -1.575786              -0.794253
# 2              -0.933479              -0.717076               0.820150
# 3               0.106354               1.192475              -0.024441
# 4              -0.388503              -2.839655              -0.229767
#
#    principal component 4  principal component 5  principal component 6  \
# 0               0.116006              -3.226691              -1.928459
# 1               1.156287               0.292256               0.349060
# 2              -1.547638               0.173941               0.272783
# 3               1.507469              -2.356836              -0.023139
# 4              -0.622510               0.271458              -0.928956
#
#    principal component 7  principal component 8  principal component 9  \
# 0              -1.958892              -1.922997               0.026753
# 1              -0.455206               0.285332               0.689683
# 2               0.025821              -0.030817              -0.431499
# 3               0.236418              -1.717109              -1.230785
# 4               0.537900              -1.301787               0.279007
#
#    principal component 10          x          y  class
# 0                0.178144 -13.872906 -13.842432      0
# 1               -0.557031   2.307272  -5.944224      2
# 2                0.013336   0.517695  24.874369      3
# 3               -0.703400  -9.319548  11.190859      3
# 4                0.631183  19.238403 -11.190392      2

# %%
# Plot the clusters with colors according to class label
plt.scatter(df_myopia_pca['x'], df_myopia_pca['y'], c=df_myopia_pca['class'])
plt.show()

# %% [markdown]
# # Part 4: Recommendation

# %% [markdown]
# # # Myopia Clusters Findings
# Prepared the Data, Applied Dimensional Reduction using PCA and  t-SNE. grouped them into Clusters  with K-Means model. In this analysis i noticed:
#
# The optimal number of clusters seems to be ranging at 3
#
# Finding t-SNE was abit of challenge in the clusters, possibly due to randomisizing them in the the anlaysis.
#
# There was a pattern during the K-Means clustering though the data was too small to have an accurate prediction in the process of testing and training of the data
#
# ### I would recommend a much sizable data for the future Test and Training to be able to have a more accurate predictions and clustering of the patients
